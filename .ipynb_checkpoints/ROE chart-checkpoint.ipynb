# %%
import requests
import pandas as pd
import json
from api_token_file import api_token

tickers_list = ['AAPL']

for ticker in tickers_list: 
    print(f'Company ticker: {ticker}')
    fundamental_data_url = f'https://eodhd.com/api/fundamentals/{ticker}?api_token={api_token}&fmt=json'
    fundamental_data_json = requests.get(fundamental_data_url).json()
    
    is_yearly_df = pd.DataFrame.from_dict(fundamental_data_json['Financials']['Income_Statement']['yearly'])
    bs_yearly_df = pd.DataFrame.from_dict(fundamental_data_json['Financials']['Balance_Sheet']['yearly'])
    cfs_yearly_df = pd.DataFrame.from_dict(fundamental_data_json['Financials']['Cash_Flow']['yearly'])
    
    display(bs_yearly_df)
# Out:
# Company ticker: AAPL
#                                         2023-09-30       2022-09-30  \
# date                                    2023-09-30       2022-09-30
# filing_date                             2023-11-03       2022-10-28
# currency_symbol                                USD              USD
# researchDevelopment                 29915000000.00   26251000000.00
# effectOfAccountingCharges                     None             None
# incomeBeforeTax                    113736000000.00  119103000000.00
# minorityInterest                              None             None
# netIncome                           96995000000.00   99803000000.00
# sellingGeneralAdministrative        24932000000.00   25094000000.00
# sellingAndMarketingExpenses                   None             None
# grossProfit                        169148000000.00  170782000000.00
# reconciledDepreciation              11519000000.00   11104000000.00
# ebit                               114301000000.00  119437000000.00
# ebitda                             125820000000.00  130541000000.00
# depreciationAndAmortization         11519000000.00   11104000000.00
# nonOperatingIncomeNetOther            565000000.00     334000000.00
# operatingIncome                    114301000000.00  119437000000.00
# otherOperatingExpenses             268984000000.00  274891000000.00
# interestExpense                      3933000000.00    2931000000.00
# taxProvision                        16741000000.00   19300000000.00
# interestIncome                        183000000.00     106000000.00
# netInterestIncome                    -183000000.00    -106000000.00
# extraordinaryItems                            None             None
# nonRecurring                                  None             None
# otherItems                                    None             None
# incomeTaxExpense                    16741000000.00   19300000000.00
# totalRevenue                       383285000000.00  394328000000.00
# totalOperatingExpenses              54847000000.00   51345000000.00
# costOfRevenue                      214137000000.00  223546000000.00
# totalOtherIncomeExpenseNet           -565000000.00    -334000000.00
# discontinuedOperations                        None             None
# netIncomeFromContinuingOps          96995000000.00   99803000000.00
# netIncomeApplicableToCommonShares   96995000000.00   99803000000.00
# preferredStockAndOtherAdjustments             None             None
#
#                                         2021-09-30       2020-09-30  \
# date                                    2021-09-30       2020-09-30
# filing_date                             2021-10-29       2020-10-30
# currency_symbol                                USD              USD
# researchDevelopment                 21914000000.00   18752000000.00
# effectOfAccountingCharges                     None             None
# incomeBeforeTax                    109207000000.00   67091000000.00
# minorityInterest                              None             None
# netIncome                           94680000000.00   57411000000.00
# sellingGeneralAdministrative        21973000000.00   19916000000.00
# sellingAndMarketingExpenses                   None             None
# grossProfit                        152836000000.00  104956000000.00
# reconciledDepreciation              11284000000.00   11056000000.00
# ebit                               108949000000.00   66288000000.00
# ebitda                             120233000000.00   77344000000.00
# depreciationAndAmortization         11284000000.00   11056000000.00
# nonOperatingIncomeNetOther            258000000.00     803000000.00
# operatingIncome                    108949000000.00   66288000000.00
# otherOperatingExpenses             256868000000.00  208227000000.00
# interestExpense                      2645000000.00    2873000000.00
# taxProvision                        14527000000.00    9680000000.00
# interestIncome                       2843000000.00    3763000000.00
# netInterestIncome                     198000000.00     890000000.00
# extraordinaryItems                            None             None
# nonRecurring                                  None             None
# otherItems                                    None             None
# incomeTaxExpense                    14527000000.00    9680000000.00
# totalRevenue                       365817000000.00  274515000000.00
# totalOperatingExpenses              43887000000.00   38668000000.00
# costOfRevenue                      212981000000.00  169559000000.00
# totalOtherIncomeExpenseNet            258000000.00     803000000.00
# discontinuedOperations                        None             None
# netIncomeFromContinuingOps          94680000000.00   57411000000.00
# netIncomeApplicableToCommonShares   94680000000.00   57411000000.00
# preferredStockAndOtherAdjustments             None             None
#
#                                         2019-09-30       2018-09-30  \
# date                                    2019-09-30       2018-09-30
# filing_date                             2019-10-31       2018-11-05
# currency_symbol                                USD              USD
# researchDevelopment                 16217000000.00   14236000000.00
# effectOfAccountingCharges                     None             None
# incomeBeforeTax                     65737000000.00   72903000000.00
# minorityInterest                              None             None
# netIncome                           55256000000.00   59531000000.00
# sellingGeneralAdministrative        18245000000.00   16705000000.00
# sellingAndMarketingExpenses                   None             None
# grossProfit                         98392000000.00  101839000000.00
# reconciledDepreciation              12547000000.00   10903000000.00
# ebit                                63930000000.00   70898000000.00
# ebitda                              76477000000.00   81801000000.00
# depreciationAndAmortization         12547000000.00   10903000000.00
# nonOperatingIncomeNetOther           1807000000.00    2005000000.00
# operatingIncome                     63930000000.00   70898000000.00
# otherOperatingExpenses             196244000000.00  194697000000.00
# interestExpense                      3576000000.00    3240000000.00
# taxProvision                        10481000000.00   13372000000.00
# interestIncome                       4961000000.00    5686000000.00
# netInterestIncome                    1385000000.00    2446000000.00
# extraordinaryItems                            None   -1515000000.00
# nonRecurring                                  None             None
# otherItems                                    None             None
# incomeTaxExpense                    10481000000.00   13372000000.00
# totalRevenue                       260174000000.00  265595000000.00
# totalOperatingExpenses              34462000000.00   30941000000.00
# costOfRevenue                      161782000000.00  163756000000.00
# totalOtherIncomeExpenseNet           1807000000.00    2005000000.00
# discontinuedOperations                        None             None
# netIncomeFromContinuingOps          55256000000.00   59531000000.00
# netIncomeApplicableToCommonShares   55256000000.00   59531000000.00
# preferredStockAndOtherAdjustments             None             None
#
#                                         2017-09-30       2016-09-30  \
# date                                    2017-09-30       2016-09-30
# filing_date                             2017-11-03       2016-10-26
# currency_symbol                                USD              USD
# researchDevelopment                 11581000000.00   10045000000.00
# effectOfAccountingCharges                     None             None
# incomeBeforeTax                     64089000000.00   61372000000.00
# minorityInterest                              None             None
# netIncome                           48351000000.00   45687000000.00
# sellingGeneralAdministrative        15261000000.00   14194000000.00
# sellingAndMarketingExpenses                   None             None
# grossProfit                         88186000000.00   84263000000.00
# reconciledDepreciation              10157000000.00             None
# ebit                                61344000000.00   60024000000.00
# ebitda                              71501000000.00   70529000000.00
# depreciationAndAmortization         10157000000.00   10505000000.00
# nonOperatingIncomeNetOther           2745000000.00    1348000000.00
# operatingIncome                     61344000000.00   62567000000.00
# otherOperatingExpenses             167890000000.00  155615000000.00
# interestExpense                      2323000000.00    1456000000.00
# taxProvision                        15738000000.00   15685000000.00
# interestIncome                       5201000000.00    3999000000.00
# netInterestIncome                    2878000000.00    2543000000.00
# extraordinaryItems                            None             None
# nonRecurring                                  None             None
# otherItems                                    None             None
# incomeTaxExpense                    15738000000.00   15685000000.00
# totalRevenue                       229234000000.00  215639000000.00
# totalOperatingExpenses              26842000000.00   24239000000.00
# costOfRevenue                      141048000000.00  131376000000.00
# totalOtherIncomeExpenseNet           2745000000.00    1348000000.00
# discontinuedOperations                        None             None
# netIncomeFromContinuingOps          48351000000.00   45687000000.00
# netIncomeApplicableToCommonShares   48351000000.00   45687000000.00
# preferredStockAndOtherAdjustments             None             None
#
#                                         2015-09-30       2014-09-30  ...  \
# date                                    2015-09-30       2014-09-30  ...
# filing_date                             2015-10-28       2014-10-27  ...
# currency_symbol                                USD              USD  ...
# researchDevelopment                  8067000000.00    6041000000.00  ...
# effectOfAccountingCharges                     None             None  ...
# incomeBeforeTax                     72515000000.00   53483000000.00  ...
# minorityInterest                              None             None  ...
# netIncome                           53394000000.00   39510000000.00  ...
# sellingGeneralAdministrative        14329000000.00   11993000000.00  ...
# sellingAndMarketingExpenses                   None             None  ...
# grossProfit                         93626000000.00   70537000000.00  ...
# reconciledDepreciation                        None             None  ...
# ebit                                71230000000.00   53867000000.00  ...
# ebitda                              82487000000.00   61813000000.00  ...
# depreciationAndAmortization         11257000000.00    7946000000.00  ...
# nonOperatingIncomeNetOther           1285000000.00     980000000.00  ...
# operatingIncome                     71230000000.00   52503000000.00  ...
# otherOperatingExpenses             162485000000.00  130292000000.00  ...
# interestExpense                       733000000.00     384000000.00  ...
# taxProvision                        19121000000.00             None  ...
# interestIncome                                None             None  ...
# netInterestIncome                             None             None  ...
# extraordinaryItems                            None             None  ...
# nonRecurring                                  None             None  ...
# otherItems                                    None             None  ...
# incomeTaxExpense                    19121000000.00   13973000000.00  ...
# totalRevenue                       233715000000.00  182795000000.00  ...
# totalOperatingExpenses              22396000000.00   18034000000.00  ...
# costOfRevenue                      140089000000.00  112258000000.00  ...
# totalOtherIncomeExpenseNet           1285000000.00     980000000.00  ...
# discontinuedOperations                        None             None  ...
# netIncomeFromContinuingOps          53394000000.00   39510000000.00  ...
# netIncomeApplicableToCommonShares   53394000000.00   39510000000.00  ...
# preferredStockAndOtherAdjustments             None             None  ...
#
#                                       1994-09-30     1993-09-30  \
# date                                  1994-09-30     1993-09-30
# filing_date                           1994-12-13     1993-09-30
# currency_symbol                              USD            USD
# researchDevelopment                 564303000.00           None
# effectOfAccountingCharges                   None           None
# incomeBeforeTax                     500286000.00   139700000.00
# minorityInterest                            None           None
# netIncome                           310178000.00    86600000.00
# sellingGeneralAdministrative       1384111000.00  2617800000.00
# sellingAndMarketingExpenses                 None           None
# grossProfit                        2343833000.00  2894300000.00
# reconciledDepreciation                      None           None
# ebit                                447388000.00    81100000.00
# ebitda                              615346000.00   247200000.00
# depreciationAndAmortization         167958000.00   166100000.00
# nonOperatingIncomeNetOther                  None           None
# operatingIncome                     522274000.00    81100000.00
# otherOperatingExpenses             8793329000.00  7866600000.00
# interestExpense                      39653000.00    58600000.00
# taxProvision                                None           None
# interestIncome                              None           None
# netInterestIncome                           None           None
# extraordinaryItems                          None           None
# nonRecurring                                None           None
# otherItems                                  None           None
# incomeTaxExpense                    190108000.00    53100000.00
# totalRevenue                       9188748000.00  7977000000.00
# totalOperatingExpenses             1948414000.00  2783900000.00
# costOfRevenue                      6844915000.00  5082700000.00
# totalOtherIncomeExpenseNet          -21988000.00    58600000.00
# discontinuedOperations                      None           None
# netIncomeFromContinuingOps                  None           None
# netIncomeApplicableToCommonShares           None           None
# preferredStockAndOtherAdjustments           None           None
#
#                                       1992-09-30     1991-09-30  \
# date                                  1992-09-30     1991-09-30
# filing_date                           1992-09-30     1991-09-30
# currency_symbol                              USD            USD
# researchDevelopment                         None           None
# effectOfAccountingCharges                   None           None
# incomeBeforeTax                     855500000.00   499700000.00
# minorityInterest                            None           None
# netIncome                           530400000.00   309800000.00
# sellingGeneralAdministrative       2289400000.00  2547400000.00
# sellingAndMarketingExpenses                 None           None
# grossProfit                        3312300000.00  3199100000.00
# reconciledDepreciation                      None           None
# ebit                                756100000.00   394900000.00
# ebitda                              973300000.00   599300000.00
# depreciationAndAmortization         217200000.00   204400000.00
# nonOperatingIncomeNetOther                  None           None
# operatingIncome                     805700000.00   447300000.00
# otherOperatingExpenses             6280800000.00  5861500000.00
# interestExpense                      99400000.00   104800000.00
# taxProvision                                None           None
# interestIncome                              None           None
# netInterestIncome                           None           None
# extraordinaryItems                          None           None
# nonRecurring                                None           None
# otherItems                                  None           None
# incomeTaxExpense                    325100000.00   189900000.00
# totalRevenue                       7086500000.00  6308800000.00
# totalOperatingExpenses             2506600000.00  2751800000.00
# costOfRevenue                      3774200000.00  3109700000.00
# totalOtherIncomeExpenseNet           49800000.00    52400000.00
# discontinuedOperations                      None           None
# netIncomeFromContinuingOps                  None           None
# netIncomeApplicableToCommonShares           None           None
# preferredStockAndOtherAdjustments           None           None
#
#                                       1990-09-30     1989-09-30  \
# date                                  1990-09-30     1989-09-30
# filing_date                           1990-09-30     1989-09-30
# currency_symbol                              USD            USD
# researchDevelopment                         None           None
# effectOfAccountingCharges                   None           None
# incomeBeforeTax                     778500000.00   744300000.00
# minorityInterest                            None           None
# netIncome                           474900000.00   454000000.00
# sellingGeneralAdministrative       2240200000.00  1954900000.00
# sellingAndMarketingExpenses                 None           None
# grossProfit                        3154900000.00  2714000000.00
# reconciledDepreciation                      None           None
# ebit                                645500000.00   524300000.00
# ebitda                              848200000.00   649100000.00
# depreciationAndAmortization         202700000.00   124800000.00
# nonOperatingIncomeNetOther                  None           None
# operatingIncome                     712000000.00   634300000.00
# otherOperatingExpenses             4846400000.00  4649700000.00
# interestExpense                     133000000.00   220000000.00
# taxProvision                                None           None
# interestIncome                              None           None
# netInterestIncome                           None           None
# extraordinaryItems                          None           None
# nonRecurring                                None           None
# otherItems                                  None           None
# incomeTaxExpense                    303600000.00   290300000.00
# totalRevenue                       5558400000.00  5284000000.00
# totalOperatingExpenses             2442900000.00  2079700000.00
# costOfRevenue                      2403500000.00  2570000000.00
# totalOtherIncomeExpenseNet           66500000.00   110000000.00
# discontinuedOperations                      None           None
# netIncomeFromContinuingOps                  None           None
# netIncomeApplicableToCommonShares           None           None
# preferredStockAndOtherAdjustments           None           None
#
#                                       1988-09-30     1987-09-30  \
# date                                  1988-09-30     1987-09-30
# filing_date                           1988-09-30     1987-09-30
# currency_symbol                              USD            USD
# researchDevelopment                         None           None
# effectOfAccountingCharges                   None           None
# incomeBeforeTax                     656200000.00   410400000.00
# minorityInterest                            None           None
# netIncome                           400300000.00   217500000.00
# sellingGeneralAdministrative       1460200000.00   993400000.00
# sellingAndMarketingExpenses                 None           None
# grossProfit                        2158200000.00  1435400000.00
# reconciledDepreciation                      None           None
# ebit                                584500000.00   332600000.00
# ebitda                              662200000.00   403100000.00
# depreciationAndAmortization          77700000.00    70500000.00
# nonOperatingIncomeNetOther                  None           None
# operatingIncome                     620300000.00   371500000.00
# otherOperatingExpenses             3451100000.00  2289600000.00
# interestExpense                      71700000.00    77800000.00
# taxProvision                                None           None
# interestIncome                              None           None
# netInterestIncome                           None           None
# extraordinaryItems                          None           None
# nonRecurring                                None           None
# otherItems                                  None           None
# incomeTaxExpense                    255900000.00   192900000.00
# totalRevenue                       4071400000.00  2661100000.00
# totalOperatingExpenses             1537900000.00  1063900000.00
# costOfRevenue                      1913200000.00  1225700000.00
# totalOtherIncomeExpenseNet           35900000.00    38900000.00
# discontinuedOperations                      None           None
# netIncomeFromContinuingOps                  None           None
# netIncomeApplicableToCommonShares           None           None
# preferredStockAndOtherAdjustments           None           None
#
#                                       1986-09-30     1985-09-30
# date                                  1986-09-30     1985-09-30
# filing_date                           1986-09-30     1985-09-30
# currency_symbol                              USD            USD
# researchDevelopment                         None           None
# effectOfAccountingCharges                   None           None
# incomeBeforeTax                     309800000.00   120000000.00
# minorityInterest                            None           None
# netIncome                           154000000.00    61200000.00
# sellingGeneralAdministrative        737300000.00   653200000.00
# sellingAndMarketingExpenses                 None           None
# grossProfit                        1061900000.00   842300000.00
# reconciledDepreciation                      None           None
# ebit                                237300000.00   174500000.00
# ebitda                              288400000.00   216300000.00
# depreciationAndAmortization          51100000.00    41800000.00
# nonOperatingIncomeNetOther                  None           None
# operatingIncome                     273500000.00   147300000.00
# otherOperatingExpenses             1628400000.00  1771000000.00
# interestExpense                      72500000.00    54500000.00
# taxProvision                                None           None
# interestIncome                              None           None
# netInterestIncome                           None           None
# extraordinaryItems                          None           None
# nonRecurring                                None           None
# otherItems                                  None           None
# incomeTaxExpense                    155800000.00    58800000.00
# totalRevenue                       1901900000.00  1918300000.00
# totalOperatingExpenses              788400000.00   695000000.00
# costOfRevenue                       840000000.00  1076000000.00
# totalOtherIncomeExpenseNet           36300000.00   -27300000.00
# discontinuedOperations                      None           None
# netIncomeFromContinuingOps                  None           None
# netIncomeApplicableToCommonShares           None           None
# preferredStockAndOtherAdjustments           None           None
#
# [34 rows x 39 columns]
